# %% [markdown]
# # 🎵 Music & Mental Health — Exploratory Data Analysis
#
# **Dataset:** Music & Mental Health Survey (~700 filas)
# **Objetivo:** Predecir si escuchar música mejora, empeora o no afecta la salud mental
# **Target:** `Music effects` → `Improve` / `No effect` / `Worsen`
#
# ---
#
# Usa **Claude Code** como pair programmer en cada celda marcada con `TODO`.

# %% [markdown]
# ## 0. Setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style='whitegrid')
# %matplotlib inline

DATA_PATH = '../data/train.csv'

# %% [markdown]
# ## 1. Carga y vista general

# %%
df = pd.read_csv(DATA_PATH)
df.head()

# %%
# TODO: Usar Claude Code para obtener un resumen completo del dataset
# Pista: shape, dtypes, describe(), value_counts del target

# %%
# TODO: Identificar columnas con valores nulos y calcular el porcentaje de missing por columna

# %% [markdown]
# ## 2. Distribución del target

# %%
# TODO: Graficar la distribución de 'Music effects' con un countplot
# Asegúrate de que el gráfico tenga título y etiquetas de ejes

# %% [markdown]
# ## 3. Outliers en 'Hours per day'

# %%
# TODO: Usar Claude Code para identificar y visualizar outliers en 'Hours per day'
# Pista: boxplot + regla del IQR

# %% [markdown]
# ## 4. Feature Engineering

# %%
# TODO: Con ayuda de Claude, crear la columna 'mental_health_score'
# Definición: promedio de Anxiety, Depression, Insomnia y OCD

# df['mental_health_score'] = ...

# %%
# TODO: Pedirle a Claude que sugiera una agrupación de géneros y aplicarla
# Crear la columna 'genre_group' a partir de 'Fav genre'

# genre_map = {...}
# df['genre_group'] = df['Fav genre'].map(genre_map)

# %%
# TODO: Crear la columna 'high_listener'
# Definición: 1 si 'Hours per day' > 4, 0 en caso contrario

# df['high_listener'] = ...

# %% [markdown]
# ## 5. Análisis de correlaciones

# %%
# TODO: Generar un heatmap de correlaciones entre las variables numéricas
# Incluir las nuevas features creadas

# %% [markdown]
# ## 6. Variables más relevantes para el target

# %%
# TODO: Pedirle a Claude Code que sugiera qué variables son más relevantes
# para predecir 'Music effects' y justifique con visualizaciones

# %% [markdown]
# ---
#
# ## ✅ Checkpoint Bloque 1
#
# Antes de continuar al Bloque 2, verifica que:
#
# - [ ] `mental_health_score` está creada y tiene valores razonables
# - [ ] `genre_group` agrupa correctamente los géneros
# - [ ] `high_listener` es una columna binaria (0/1)
# - [ ] Identificaste al menos 2 outliers o patrones interesantes en el EDA
#
# **Siguiente paso:** Bloque 2 — pasar este código a `src/features.py`
